# %%
import os
from dotenv import load_dotenv
from openai import OpenAI, AsyncOpenAI
from agents import Agent, Runner, OpenAIChatCompletionsModel

load_dotenv()
# Out:
# True

# %%
local_model = OpenAIChatCompletionsModel(
    model="minimax-m2:cloud",
    openai_client=AsyncOpenAI(base_url="http://127.0.0.1:11434/v1", api_key="ollama"),
)

# %%
agent = Agent(
    name="Greeter",
    instructions="You are a friendly assistant. Be concise",
    model=local_model,
)
result = await Runner.run(agent, "Waht is the capital of Pakistan")

print(result.final_output)
# Out:
# The capital of Pakistan is **Islamabad**. It became the capital in 1967, replacing Karachi.
# OPENAI_API_KEY is not set, skipping trace export

# %%
agent = Agent(
    name="Analyst", instructions="You analyze topics briefly.", model=local_model
)

result = await Runner.run(agent, "Why is Python popular for AI?")

# The key properties of RunResult:
print("=" * 50)
print(f"Final Output:  {result.final_output[:100]}...")  # The text response
print(f"Last Agent:    {result.last_agent.name}")  # Which agent finished
print(f"New Items:     {len(result.new_items)}")  # Items generated during run
print(f"Raw Responses: {len(result.raw_responses)}")  # Raw LLM responses
print("=" * 50)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# ==================================================
# Final Output:
# Python’s rise to the top language for artificial‑intelligence work comes from a blend of technical,...
# Last Agent:    Analyst
# New Items:     1
# Raw Responses: 1
# ==================================================
# OPENAI_API_KEY is not set, skipping trace export

# %%
agent = Agent(
    name="Tutor",
    instructions="You are a Python tutor. Be concise. Remember context from previous messages.",
    model=local_model,
)

# Turn 1
result = await Runner.run(agent, "What is a list in Python?")
print(f"Turn 1: {result.final_output}\n")

# Turn 2 — carry conversation history forward
new_input = result.to_input_list() + [{"role": "user", "content": "How do I sort one?"}]
result = await Runner.run(agent, new_input)
print(f"Turn 2: {result.final_output}\n")

# Turn 3
new_input = result.to_input_list() + [
    {"role": "user", "content": "What about reverse sort?"}
]
result = await Runner.run(agent, new_input)
print(f"Turn 3: {result.final_output}")
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# Turn 1: A **list** in Python is an ordered, mutable collection of items that can hold elements of different types.
#
# ## Key Features
# - **Ordered** – items maintain their insertion order
# - **Mutable** – you can modify, add, or remove items
# - **Dynamic** – can grow or shrink as needed
#
# ## Creating a List
# ```python
# # Empty list
# my_list = []
#
# # With items
# fruits = ["apple", "banana", "cherry"]
# mixed = [1, "hello", 3.14, True]
# ```
#
# ## Common Operations
# ```python
# fruits = ["apple", "banana", "cherry"]
#
# # Access by index
# fruits[0]   # "apple"
#
# # Modify
# fruits[1] = "orange"
#
# # Add items
# fruits.append("grape")       # at end
# fruits.insert(1, "mango")    # at specific index
#
# # Remove items
# fruits.remove("apple")       # by value
# fruits.pop()                 # remove last item
#
# # Other useful methods
# len(fruits)        # length
# "banana" in fruits # membership check
# ```
#
# Lists are one of Python's most versatile data structures and are used extensively in programming.
# OPENAI_API_KEY is not set, skipping trace export
# Turn 2: You can sort a list in two ways:
#
# ## 1. `sort()` – sorts in place (modifies original list)
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6]
# numbers.sort()
# print(numbers)  # [1, 1, 2, 3, 4, 5, 6, 9]
#
# # Sort in reverse
# numbers.sort(reverse=True)
# ```
#
# ## 2. `sorted()` – returns a new sorted list (original unchanged)
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6]
# sorted_nums = sorted(numbers)
# print(sorted_nums)  # [1, 1, 2, 3, 4, 5, 6, 9]
# print(numbers)      # [3, 1, 4, 1, 5, 9, 2, 6] - unchanged
# ```
#
# ## Sorting with a Key
# ```python
# # By length of string
# words = ["cat", "elephant", "dog"]
# words.sort(key=len)
# # ["cat", "dog", "elephant"]
#
# # Case-insensitive sorting
# words = ["Banana", "apple", "Cherry"]
# words.sort(key=str.lower)
# # ["apple", "Banana", "Cherry"]
# ```
#
# **When to use which:**
# - Use `sort()` when you don't need the original order
# - Use `sorted()` when you need to preserve the original list
# OPENAI_API_KEY is not set, skipping trace export
# Turn 3: Two simple ways to reverse sort:
#
# ## 1. Using `reverse=True`
# ```python
# numbers = [3, 1, 4, 1, 5]
# numbers.sort(reverse=True)
# print(numbers)  # [5, 4, 3, 1, 1]
#
# # With sorted()
# result = sorted(numbers, reverse=True)
# ```
#
# ## 2. Using `reverse()` method
# This simply reverses the list order (doesn't sort):
#
# ```python
# numbers = [1, 5, 3, 2, 4]
# numbers.reverse()
# print(numbers)  # [4, 2, 3, 5, 1]
# ```
#
# **Quick comparison:**
#
# | Method | What it does |
# |--------|--------------|
# | `sort(reverse=True)` | Sorts highest to lowest |
# | `sorted(list, reverse=True)` | Sorts highest to lowest, returns new list |
# | `list.reverse()` | Just flips the order, no sorting |
#
# For reverse sorting, use the first two. Use `reverse()` only when you want to flip an already-sorted list.
# OPENAI_API_KEY is not set, skipping trace export

# %%
agent = Agent(name="Streamer", instructions="Explain briefly.", model=local_model)

# Streaming — see tokens as they arrive
result = Runner.run_streamed(agent, "What is machine learning in 2 sentences?")

async for event in result.stream_events():
    if event.type == "raw_response_event" and hasattr(event.data, "delta"):
        print(event.data.delta, end="", flush=True)

print(f"\n\n--- Final: {result.final_output}")
# Out:
# The user
# OPENAI_API_KEY is not set, skipping trace export
#  asks: "What is machine learning in 2 sentences?" The developer says: "Explain briefly."
#
# We need to respond with exactly 2 sentences that explain what machine learning is, briefly. No extra sentences.
#
# We should obey the user request: provide a brief explanation in two sentences. The developer says "Explain briefly." This seems consistent.
#
# Thus we must give exactly two sentences. Perhaps:
#
# "Machine learning is a subset of artificial intelligence that enables systems to automatically learn and improve from experience without being explicitly programmed. It uses algorithms to identify patterns in data, make predictions, and inform decision‑making."
#
# That's two sentences. Yes.
#
# We need to ensure no extra sentences beyond that. Also note any disallowed content? It's fine.
#
# Thus answer: 2 sentences.Machine learning is a subset of artificial intelligence that enables systems to automatically learn and improve from experience without being explicitly programmed. It uses algorithms to identify patterns in data, make predictions, and inform decision‑making.
#
# --- Final: Machine learning is a subset of artificial intelligence that enables systems to automatically learn and improve from experience without being explicitly programmed. It uses algorithms to identify patterns in data, make predictions, and inform decision‑making.
# OPENAI_API_KEY is not set, skipping trace export
