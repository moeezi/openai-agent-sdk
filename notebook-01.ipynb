# %%
import asyncio
from agents import Agent, Runner, function_tool, OpenAIChatCompletionsModel

# %%
# async def test():
#     print("Hello")
#     await async.sleep(1)
# print("...world!")

asyncio.run

# %%
history_agent = Agent(
    model="minimax-m2:cloud",
    name="History Tutor",
    instructions="You answer for history questions clearly and concisly",
)

# %%
result = Runner.run(history_agent, "who is built badshai masjid in lahore pakistan")

# %%
print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(result.final_output)
#
# AttributeError: 'coroutine' object has no attribute 'final_output'
